# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
bmi_life_data = pd.read_csv("bmi_and_life_expectancy.csv")

# %%
bmi_life_model = LinearRegression()
bmi_life_model.fit(bmi_life_data[['BMI']],bmi_life_data[['Life expectancy']])

laos_life_exp = bmi_life_model.predict([ [21.07931]])
print(laos_life_exp)
# Out:
# [[60.31564716]]

# %%
ax = plt.scatter(bmi_life_data[['BMI']], bmi_life_data[['Life expectancy']])
plt.title('bmi_and_life_expectancy(LinearRegression)')
plt.xlabel("BMI")
plt.ylabel("Life expectancy")
print("coef_:",bmi_life_model.coef_)
print("intercept_:",bmi_life_model.intercept_)
x = np.linspace(18, 30, 1000)
y = bmi_life_model.coef_[0][0] *x+ bmi_life_model.intercept_[0]
A = [0,bmi_life_model.intercept_[0]]
B = [-bmi_life_model.intercept_[0]/bmi_life_model.coef_[0][0],0]
plt.plot(x,y,c='r')
# Out:
# coef_: [[2.51847944]]
# intercept_: [7.22783834]

# %%
from sklearn import linear_model
reg = linear_model.Ridge (alpha = .505)
reg.fit(bmi_life_data[['BMI']],bmi_life_data[['Life expectancy']])
print(reg.predict([ [21.07931]]))
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
# Out:
# [[60.32058978]]
# coef_: [[2.5171483]]
# intercept_: [7.26084046]

# %%
ax = plt.scatter(bmi_life_data[['BMI']], bmi_life_data[['Life expectancy']])
plt.title('bmi_and_life_expectancy(Ridge Regression)')
plt.xlabel("BMI")
plt.ylabel("Life expectancy-")
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
x = np.linspace(18, 30, 1000)
y = reg.coef_[0][0] *x+ reg.intercept_[0]
A = [0,reg.intercept_[0]]
B = [-reg.intercept_[0]/reg.coef_[0][0],0]
plt.plot(x,y,c='r')
# Out:
# coef_: [[2.5171483]]
# intercept_: [7.26084046]

# %%
reg = linear_model.RidgeCV(alphas=[0.1, 1.0, 10.0])
reg.fit(bmi_life_data[['BMI']],bmi_life_data[['Life expectancy']])
print(reg.predict([ [21.07931]]))
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
# Out:
# [[60.41255759]]
# coef_: [[2.49237961]]
# intercept_: [7.87491509]

# %%
ax = plt.scatter(bmi_life_data[['BMI']], bmi_life_data[['Life expectancy']])
plt.title('bmi_and_life_expectancy(RidgeCV Regression)')
plt.xlabel("BMI")
plt.ylabel("Life expectancy-")
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
x = np.linspace(18, 30, 1000)
y = reg.coef_[0][0] *x+ reg.intercept_[0]
A = [0,reg.intercept_[0]]
B = [-reg.intercept_[0]/reg.coef_[0][0],0]
plt.plot(x,y,c='r')
# Out:
# coef_: [[2.49237961]]
# intercept_: [7.87491509]

# %%
#Lasso
reg = linear_model.Lasso(alpha=0.5)
reg.fit(bmi_life_data[['BMI']],bmi_life_data[['Life expectancy']])
print(reg.predict([ [21.07931]]))
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
# Out:
# [60.6325411]
# coef_: [2.43313386]
# intercept_: [9.34375819]

# %%
ax = plt.scatter(bmi_life_data[['BMI']], bmi_life_data[['Life expectancy']])
plt.title('bmi_and_life_expectancy(Lasso Regression)')
plt.xlabel("BMI")
plt.ylabel("Life expectancy-")
print("coef_:",reg.coef_)
print("intercept_:",reg.intercept_)
x = np.linspace(18, 30, 1000)
y = reg.coef_[0] *x+ reg.intercept_[0]
A = [0,reg.intercept_[0]]
B = [-reg.intercept_[0]/reg.coef_[0],0]
plt.plot(x,y,c='r')
# Out:
# coef_: [2.43313386]
# intercept_: [9.34375819]
